# %% [markdown]
# ![task1.jpg](attachment:task1.jpg)

# %%
good_marks = 37
math = 15
phys = 16
chem = 19
m_p = 7
p_c = 6
m_c = 9
all = 4
print(f'{((math+phys+chem)-m_p-m_c-p_c+all)} students received at least one excellent grade')
# Out:
# 32 students received at least one excellent grade
