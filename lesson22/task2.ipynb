# %% [markdown]
# ![task2.jpg](attachment:task2.jpg)

# %%
days = 30
rainy = 12
windy = 8
cold = 4
r_w = 5
r_c = 3
w_c = 2
bad_day = 1
print(f'weather was good for {rainy+windy+cold-r_c-r_w-w_c+bad_day} days')
# Out:
# weather was good for 15 days
