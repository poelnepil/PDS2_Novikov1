# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **task1**

# %%
tb = pd.read_excel('cars.xlsx')
tb
# Out:
#                  marks  price/$  maximum speed/km  load capacity/kg  \
# 0               bmw x5    33000               230               715
# 1          lexus rx300    55000               200               600
# 2              audi a5    19000               250               530
# 3    volkswagen passat    22000               238               630
# 4        tesla model x    60000               250              2200
# 5   toyota cruiser 200    35000               210              1000
# 6        jeep wrangler    24000               199               800
# 7       hyundai accent    10000               193               500
# 8            mazda rx8     5000               220              1000
# 9            nissan nv    15000               161              1200
# 10   chevrolet cruze 7     7000               185               700
# 11              kia k7    12000               258               500
# 12        ford mustang    17000               290              1000
# ...

# %% [markdown]
# **task2**

# %%
plt.plot(sorted(tb['gasoline consumption liters/100km']),sorted(tb['price/$']), color = 'red', linewidth = 3)

# %%
plt.scatter(sorted(tb['gasoline consumption liters/100km']),sorted(tb['maximum speed/km']), color = 'black', marker = 'D')

# %%
plt.scatter(sorted(tb['load capacity/kg']), sorted(tb['maximum speed/km']), color = 'blue', marker = 'D')

# %% [markdown]
# **task3**

# %%
plt.hist(tb['maximum speed/km'], 5, color = 'green')
# Out:
# (array([3., 8., 6., 2., 1.]),
#  array([145., 182., 219., 256., 293., 330.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# **task4**

# %%
sns.boxplot(x = 'maximum speed/km', y = 'marks', data = tb)
# Out:
# <AxesSubplot: xlabel='maximum speed/km', ylabel='marks'>

# %% [markdown]
# **task5**

# %%
sns.pairplot(tb)
