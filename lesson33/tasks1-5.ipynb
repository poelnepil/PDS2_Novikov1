# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **task1**

# %%
tb = pd.read_excel('cars.xlsx')
tb['price/$'] = tb['price/$'] / 1000
tb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tb = pd.read_excel('cars.xlsx')
#       2 tb['price/$'] = tb['price/$'] / 1000
#       3 tb
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %% [markdown]
# **task2**

# %%
plt.plot(tb['gasoline consumption liters/100km'],tb['price/$'], color = 'red', linewidth = 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(tb['gasoline consumption liters/100km'],tb['price/$'], color = 'red', linewidth = 3)
#
# NameError: name 'tb' is not defined

# %%
plt.scatter(tb['gasoline consumption liters/100km'], tb['maximum speed/km'], color = 'black', marker = 'D')

# %%
plt.scatter(tb['load capacity/kg'], tb['maximum speed/km'], color = 'blue', marker = 'D')

# %% [markdown]
# **task3**

# %%
plt.hist(tb['maximum speed/km'], 5, color = 'green')
# Out:
# (array([3., 8., 6., 2., 1.]),
#  array([145., 182., 219., 256., 293., 330.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# **task4**

# %%
sns.boxplot(x = 'maximum speed/km', y = 'marks', data = tb)
# Out:
# <AxesSubplot: xlabel='maximum speed/km', ylabel='marks'>

# %% [markdown]
# **task5**

# %%
sns.pairplot(tb)
