# %%
import numpy as np
import tensorflow_datasets as tfds

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
(train, test), metadata = tfds.load('cats_vs_dogs', split=['train[:60%]', 'train[60%:]'],
                                        with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\vanzo\tensorflow_datasets\cats_vs_dogs\4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling C:\Users\vanzo\tensorflow_datasets\cats_vs_dogs\4.0.0.incompleteUG47OJ\cats_vs_dogs-train.tfrecord*.…
# Dataset cats_vs_dogs downloaded and prepared to C:\Users\vanzo\tensorflow_datasets\cats_vs_dogs\4.0.0. Subsequent calls will reuse this data.

# %%
def vizualizate(original, augmented):
    fig = plt.figure()
    plt.subplot(1, 2, 1)
    plt.title('Original')
    plt.imshow(original)
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.title('Augmented')
    plt.imshow(augmented)
    plt.axis('off')

# %%
get_name = metadata.features['label'].int2str

# %%
image, label = next(iter(test))
plt.imshow(image)
plt.title(get_name(label))
# Out:
# Text(0.5, 1.0, 'dog')

# %%
import tensorflow as ts
fliped = ts.image.flip_left_right(image)
vizualizate(image, fliped)

# %%
gray_scale = ts.image.rgb_to_grayscale(image)
vizualizate(image, gray_scale)

# %%
brighted = ts.image.adjust_brightness(image, 0.3)
vizualizate(image, brighted)

# %%
saturated = ts.image.adjust_saturation(image, 3)
vizualizate(image, saturated)

# %%
rotated = ts.image.rot90(image)
vizualizate(image, rotated)

# %%
for i in range(3):
    seed = (i, 0)
    random_brightness = ts.image.stateless_random_brightness(image, max_delta=0.7, seed = seed)
    vizualizate(image, random_brightness)
